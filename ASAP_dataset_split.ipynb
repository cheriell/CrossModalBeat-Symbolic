# %% [markdown]
# # Dataset Split for the ASAP dataset
#
# We take five Chopin compositions from the [ASAP dataset](https://github.com/fosfrancesco/asap-dataset), among which three of the compositions are used for trianing, one for validation, and one for testing.
#
# We use the [v1.2 release](https://github.com/fosfrancesco/asap-dataset/releases) of the ASAP dataset.

# %%
import os
import pandas as pd
import pretty_midi as pm
import warnings
warnings.filterwarnings("ignore")


dataset_path = '/mnt/c/Users/lel79bc/Desktop/Datasets/asap-dataset-1.2'  # Please change this to your ASAP dataset path


#################################################
# Create dataset split
#################################################

# Get metadata
metadata = pd.read_csv(os.path.join(dataset_path, 'metadata.csv'))

# Get only the Chopin compositions
metadata = metadata[metadata['composer'] == 'Chopin']
metadata.reset_index(drop=True, inplace=True)

# Expand a "split" column to the right of the dataframe
metadata['split'] = 'train'  # Default to train split

# Get the five compositions with most performances for Chopin
compositions = []
for composition in metadata['title'].unique():
    if len(metadata[metadata['title'] == composition]) > 15:
        compositions.append(composition)
        print('Composition:', composition, '\tNumber of Performances:', len(metadata[metadata['title'] == composition]), '\tSplit:', 'train' if len(compositions) <=3 else 'val' if len(compositions) == 4 else 'test')

# Filter the metadata to only include these compositions
metadata = metadata[metadata['title'].isin(compositions)]
metadata.reset_index(drop=True, inplace=True)

# Set the last composition to the test set and the second last to the validation set
metadata.loc[metadata[metadata['title'] == compositions[-1]].index, 'split'] = 'test'
metadata.loc[metadata[metadata['title'] == compositions[-2]].index, 'split'] = 'val'
        
# Save the metadata with the new split column
metadata.to_csv('ASAP_dataset_split.csv', index=False)
metadata
# Out:
# Composition: Ballades_1 	Number of Performances: 18 	Split: train
# Composition: Etudes_op_10_1 	Number of Performances: 25 	Split: train
# Composition: Etudes_op_10_4 	Number of Performances: 22 	Split: train
# Composition: Etudes_op_10_8 	Number of Performances: 28 	Split: val
# Composition: Etudes_op_25_11 	Number of Performances: 24 	Split: test
#     composer            title                  folder  \
# 0     Chopin       Ballades_1       Chopin/Ballades/1
# 1     Chopin       Ballades_1       Chopin/Ballades/1
# 2     Chopin       Ballades_1       Chopin/Ballades/1
# 3     Chopin       Ballades_1       Chopin/Ballades/1
# 4     Chopin       Ballades_1       Chopin/Ballades/1
# ..       ...              ...                     ...
# 112   Chopin  Etudes_op_25_11  Chopin/Etudes_op_25/11
# 113   Chopin  Etudes_op_25_11  Chopin/Etudes_op_25/11
# 114   Chopin  Etudes_op_25_11  Chopin/Etudes_op_25/11
# 115   Chopin  Etudes_op_25_11  Chopin/Etudes_op_25/11
# 116   Chopin  Etudes_op_25_11  Chopin/Etudes_op_25/11
#
#                                      xml_score  \
# 0         Chopin/Ballades/1/xml_score.musicxml
# 1         Chopin/Ballades/1/xml_score.musicxml
# 2         Chopin/Ballades/1/xml_score.musicxml
# 3         Chopin/Ballades/1/xml_score.musicxml
# 4         Chopin/Ballades/1/xml_score.musicxml
# ..                                         ...
# 112  Chopin/Etudes_op_25/11/xml_score.musicxml
# 113  Chopin/Etudes_op_25/11/xml_score.musicxml
# 114  Chopin/Etudes_op_25/11/xml_score.musicxml
# 115  Chopin/Etudes_op_25/11/xml_score.musicxml
# 116  Chopin/Etudes_op_25/11/xml_score.musicxml
#
#                                 midi_score  \
# 0         Chopin/Ballades/1/midi_score.mid
# 1         Chopin/Ballades/1/midi_score.mid
# 2         Chopin/Ballades/1/midi_score.mid
# 3         Chopin/Ballades/1/midi_score.mid
# 4         Chopin/Ballades/1/midi_score.mid
# ..                                     ...
# 112  Chopin/Etudes_op_25/11/midi_score.mid
# 113  Chopin/Etudes_op_25/11/midi_score.mid
# 114  Chopin/Etudes_op_25/11/midi_score.mid
# 115  Chopin/Etudes_op_25/11/midi_score.mid
# 116  Chopin/Etudes_op_25/11/midi_score.mid
#
#                         midi_performance  \
# 0            Chopin/Ballades/1/Ali01.mid
# 1         Chopin/Ballades/1/BuiJL04M.mid
# 2            Chopin/Ballades/1/Day04.mid
# 3         Chopin/Ballades/1/Dossin05.mid
# 4           Chopin/Ballades/1/JIA06M.mid
# ..                                   ...
# 112  Chopin/Etudes_op_25/11/SunJay03.mid
# 113     Chopin/Etudes_op_25/11/Tan03.mid
# 114    Chopin/Etudes_op_25/11/Tang03.mid
# 115  Chopin/Etudes_op_25/11/WangA02M.mid
# 116   Chopin/Etudes_op_25/11/WangV02.mid
#
#                              performance_annotations  \
# 0            Chopin/Ballades/1/Ali01_annotations.txt
# 1         Chopin/Ballades/1/BuiJL04M_annotations.txt
# 2            Chopin/Ballades/1/Day04_annotations.txt
# 3         Chopin/Ballades/1/Dossin05_annotations.txt
# 4           Chopin/Ballades/1/JIA06M_annotations.txt
# ..                                               ...
# 112  Chopin/Etudes_op_25/11/SunJay03_annotations.txt
# 113     Chopin/Etudes_op_25/11/Tan03_annotations.txt
# 114    Chopin/Etudes_op_25/11/Tang03_annotations.txt
# 115  Chopin/Etudes_op_25/11/WangA02M_annotations.txt
# 116   Chopin/Etudes_op_25/11/WangV02_annotations.txt
#
#                                 midi_score_annotations  \
# 0         Chopin/Ballades/1/midi_score_annotations.txt
# 1         Chopin/Ballades/1/midi_score_annotations.txt
# 2         Chopin/Ballades/1/midi_score_annotations.txt
# 3         Chopin/Ballades/1/midi_score_annotations.txt
# 4         Chopin/Ballades/1/midi_score_annotations.txt
# ..                                                 ...
# 112  Chopin/Etudes_op_25/11/midi_score_annotations.txt
# 113  Chopin/Etudes_op_25/11/midi_score_annotations.txt
# 114  Chopin/Etudes_op_25/11/midi_score_annotations.txt
# 115  Chopin/Etudes_op_25/11/midi_score_annotations.txt
# 116  Chopin/Etudes_op_25/11/midi_score_annotations.txt
#
#                               maestro_midi_performance  \
# 0                                                  NaN
# 1    {maestro}/2017/MIDI-Unprocessed_046_PIANO046_M...
# 2                                                  NaN
# 3                                                  NaN
# 4    {maestro}/2004/MIDI-Unprocessed_SMF_12_01_2004...
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115  {maestro}/2015/MIDI-Unprocessed_R1_D2-13-20_mi...
# 116                                                NaN
#
#                              maestro_audio_performance  start  end  \
# 0                                                  NaN    NaN  NaN
# 1    {maestro}/2017/MIDI-Unprocessed_046_PIANO046_M...    NaN  NaN
# 2                                                  NaN    NaN  NaN
# 3                                                  NaN    NaN  NaN
# 4    {maestro}/2004/MIDI-Unprocessed_SMF_12_01_2004...    NaN  NaN
# ..                                                 ...    ...  ...
# 112                                                NaN    NaN  NaN
# 113                                                NaN    NaN  NaN
# 114                                                NaN    NaN  NaN
# 115  {maestro}/2015/MIDI-Unprocessed_R1_D2-13-20_mi...    NaN  NaN
# 116                                                NaN    NaN  NaN
#
#                        audio_performance  split
# 0                                    NaN  train
# 1         Chopin/Ballades/1/BuiJL04M.wav  train
# 2                                    NaN  train
# 3                                    NaN  train
# 4           Chopin/Ballades/1/JIA06M.wav  train
# ..                                   ...    ...
# 112                                  NaN   test
# 113                                  NaN   test
# 114                                  NaN   test
# 115  Chopin/Etudes_op_25/11/WangA02M.wav   test
# 116                                  NaN   test
#
# [117 rows x 14 columns]

# %%
#################################################
# Print dataset statistics
#################################################

stats_df = pd.DataFrame(columns=['split', 'num_compositions', 'num_performances', 'duration (hours)'])

for split in ['train', 'val', 'test']:
    print(f'Calculating statistics for {split} split...')
    metadata_split = metadata[metadata['split'] == split]
    
    num_compositions = metadata_split['title'].nunique()
    num_performances = len(metadata_split)
    
    # Calculate the total duration
    # Get the midi performance
    duration = 0
    for i, row in metadata_split.iterrows():
        print(f'Get duration for row {i+1}/{len(metadata)}', end='\r')
        midi_performance = os.path.join(dataset_path, row['midi_performance'])
        midi_data = pm.PrettyMIDI(midi_performance)
        duration += midi_data.get_end_time()
    print()
    
    stats_df = stats_df._append({
        'split': split,
        'num_compositions': num_compositions,
        'num_performances': num_performances,
        'duration (hours)': duration / 60 / 60  # Convert to hours
    }, ignore_index=True)

stats_df
# Out:
# Calculating statistics for train split...
# Get duration for row 65/117
# Calculating statistics for val split...
# Get duration for row 93/117
# Calculating statistics for test split...
# Get duration for row 117/117
#    split num_compositions num_performances  duration (hours)
# 0  train                3               65          4.211898
# 1    val                1               28          1.108869
# 2   test                1               24          1.435413
